# %%
import ROOT
import uproot as ur
del variables

filename = "ggH_HToSSTobbbb_MH-125_MS-15_ctau-100000_137000pb_weighted.root"
treename = "MuonSystem"
tree = ur.open(filename + ':' + treename)

variables = ['Flag2_all', 'Flag_all', 'HT']
variables.extend(tree.keys(filter_name = 'Z*')) #faster than +

variables.extend(tree.keys(filter_name = 
                           lambda s: ('RechitCluster' in s) 
                              and s.startswith(('csc', 'dt')) 
                              and s.endswith('Spread')
                ))
variables.extend(tree.keys(filter_name = 
                           lambda s: s.startswith(('csc', 'dt')) 
                              and s.endswith(('ClusterNChamber', 'ClusterTime', 'ClusterSize',
                                              'ClusterEta', 'ClusterPhi',
                                              'RechitsEta', 'RechitsPhi',
                                              'X', 'Y', 'Z'))
                ))
variables.extend(tree.keys(filter_name = 
                           lambda s: s.startswith(('jet','gHiggs'))
                              and s.endswith(('Pt','E','Eta','Phi','Time'))
                ))
variables.extend(tree.keys(filter_name = 
                           lambda s: s.startswith(('nCsc', 'nDt')) 
                              and s.endswith(('RechitClusters','Rechits'))
                ))


outFileName = 'genPltsLogxy.pdf'
inFile = ROOT.TFile.Open(filename, "READ")
tree = inFile.Get("MuonSystem")


canvas = ROOT.TCanvas("canvas")
canvas.cd()

canvas.Print(outFileName + "[")

for variable in variables:
    tree.Draw(variable)
    canvas.SetLogy(True)
    canvas.SetLogx(True)
    canvas.Print(outFileName)
    #tree.GetYaxis().SetTitle("Number of events") #dont know how to get this to work
    canvas.Clear()


canvas.Print(outFileName + "]")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file genPltsLogxy.pdf has been created
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: cannot set X axis to log scale
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Error in <THistPainter::PaintInit>: log scale requested with a negative argument (-1.000000)
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: Current canvas added to pdf file genPltsLogxy.pdf
# Info in <TCanvas::Print>: pdf file genPltsLogxy.pdf has been closed
